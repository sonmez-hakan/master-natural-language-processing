# %%
# !pip install word2number
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5568 sha256=b89ffa30873d1431fa7b0880459ac9fb0e1271f1064cbf3848ee7c8f4d001d2f
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
# Successfully built word2number
# ...

# %%
# !pip install snowballstemmer

# %%
# !pip install zemberek-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141210 sha256=3231eecdfa9a5c74e3f805829b0a9b49b956e88f5b27d8d4a5a46ca6115db1ca
#   Stored in directory: /root/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# Successfully built antlr4-python3-runtime
# ...

# %%
# !pip install zeyrek
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 931.0/931.0 kB 5.5 MB/s eta 0:00:00
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import re
import string
import random
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from word2number import w2n

# %%
text = "Metin    Hoca Uludağ Üniversitesi'nin en kral hocasıdır. Ayrıca benim    danışman hocam da Metin Hoca'dır."

# %% [markdown]
# # Metnin cümle bazında tokenlarına ayrılması

# %%
sentences = sent_tokenize(text)
sentences
# Out:
# ["Metin Hoca Uludağ Üniversitesi'nin en kral hocasıdır.",
#  "Ayrıca benim danışman hocam da Metin Hoca'dır."]

# %% [markdown]
# # Metnin kelime bazında tokenlarına ayrılması

# %%
words = word_tokenize(text)
words
# Out:
# ['Metin',
#  'Hoca',
#  'Uludağ',
#  "Üniversitesi'nin",
#  'en',
#  'kral',
#  'hocasıdır',
#  '.',
#  'Ayrıca',
#  'benim',
#  'danışman',
#  'hocam',
#  'da',
#  'Metin',
#  "Hoca'dır",
#  '.']

# %% [markdown]
# # Örnek durma kelimelerinin gösterilmesi

# %%
stop_words = set(stopwords.words('turkish'))
print(list(stop_words)[:10])
print(random.sample(list(stop_words), 10))
# Out:
# ['ne', 'ise', 'ile', 'çok', 'belki', 'acaba', 'de', 'gibi', 'hem', 'kim']
# ['ve', 'belki', 'de', 'ya', 'sanki', 'her', 'hiç', 'mu', 'hepsi', 'kez']

# %% [markdown]
# # Metnin sadece küçük harfe dönüştürülmesi

# %%
lower_text = text.lower()
lower_text
# Out:
# "metin hoca uludağ üniversitesi'nin en kral hocasıdır. ayrıca benim danışman hocam da metin hoca'dır."

# %% [markdown]
# # Metindeki fazladan boşlukların silinmesi

# %%
clean_whitespace_text = re.sub(' +', ' ', text)
clean_whitespace_text
# Out:
# "Metin Hoca Uludağ Üniversitesi'nin en kral hocasıdır. Ayrıca benim danışman hocam da Metin Hoca'dır."

# %% [markdown]
# # Metindeki noktalama işaretlerinin silinmesi

# %%
punctuation_table = str.maketrans('', '', string.punctuation)
clean_punctuation_text = text.translate(punctuation_table)
clean_punctuation_text
# Out:
# 'Metin    Hoca Uludağ Üniversitesinin en kral hocasıdır Ayrıca benim    danışman hocam da Metin Hocadır'

# %% [markdown]
# # Metinmdeki Sayı kelimelerinin sayılara döünüştürülmesi

# %%
number_text = "five hundred twenty five thousand six hundred"
w2n.word_to_num(number_text)
# Out:
# 525600

# %%
test_words = [
  "gözlerin",
  "gözlüklerin",
  "gözlükçülerin",
  "olta",
  "kırmızılar"
]

# %% [markdown]
# # NLTK ile Türkçe stemming yapılması

# %%
from snowballstemmer import TurkishStemmer
nltk_stemmer=TurkishStemmer()

nltk_stemmer.stemWords(test_words)
# Out:
# ['göz', 'gözlük', 'gözlükçü', 'ol', 'kırmızı']

# %% [markdown]
# # Zemberek ile Türkçe kelimelere Lemmazation yapılması

# %%
from zemberek import TurkishMorphology
morphology = TurkishMorphology.create_with_defaults()
# Out:
# INFO:zemberek.morphology.turkish_morphology:TurkishMorphology instance initialized in 14.761634349822998
# 2023-12-25 12:05:08,345 - zemberek.morphology.turkish_morphology - INFO
# Msg: TurkishMorphology instance initialized in 14.761634349822998

# %%
for test_word in test_words:
 [print(parse) for parse in morphology.analyze(test_word)]
# Out:
# [göz:Noun] göz:Noun+ler:A3pl+in:Gen
# [göz:Noun] göz:Noun+ler:A3pl+in:P2sg
# [gözlük:Noun] gözlük:Noun+ler:A3pl+in:Gen
# [gözlük:Noun] gözlük:Noun+ler:A3pl+in:P2sg
# [göz:Noun] göz:Noun+A3sg|lük:Ness→Noun+ler:A3pl+in:Gen
# [göz:Noun] göz:Noun+A3sg|lük:Ness→Noun+ler:A3pl+in:P2sg
# [gözlük:Noun] gözlük:Noun+A3sg|çü:Agt→Noun+ler:A3pl+in:Gen
# [gözlük:Noun] gözlük:Noun+A3sg|çü:Agt→Noun+ler:A3pl+in:P2sg
# [göz:Noun] göz:Noun+A3sg|lük:Ness→Noun+A3sg|çü:Agt→Noun+ler:A3pl+in:Gen
# [göz:Noun] göz:Noun+A3sg|lük:Ness→Noun+A3sg|çü:Agt→Noun+ler:A3pl+in:P2sg
# [olta:Noun] olta:Noun+A3sg
# [kırmızı:Noun] kırmızı:Noun+lar:A3pl
# [kırmızı:Adj] kırmızı:Adj|Zero→Verb+Pres+lar:A3pl
# [kırmızı:Adj] kırmızı:Adj|Zero→Noun+lar:A3pl
# [kırmız:Noun] kırmız:Noun+A3sg+ı:P3sg|Zero→Verb+Pres+lar:A3pl
# [Kırmız:Noun, Prop] kırmız:Noun+A3sg+ı:P3sg|Zero→Verb+Pres+lar:A3pl
# [kırmızı:Noun] kırmızı:Noun+A3sg|Zero→Verb+Pres+lar:A3pl

# %% [markdown]
# # Zeyrek ile Türkçe kelimelere Lemmazation yapılması

# %%
import zeyrek
zeyrek_analyzer = zeyrek.MorphAnalyzer()

# %%
for test_word in test_words:
 [parse for parse in zeyrek_analyzer.analyze(test_word)]
# Out:
# WARNING:zeyrek.rulebasedanalyzer:APPENDING RESULT: <(göz_Noun)(-)(göz:noun_S + ler:a3pl_S + pnon_S + in:gen_ST)>
# 2023-12-25 12:16:55,886 - zeyrek.rulebasedanalyzer - WARNING
# Msg: APPENDING RESULT: <(göz_Noun)(-)(göz:noun_S + ler:a3pl_S + pnon_S + in:gen_ST)>
# WARNING:zeyrek.rulebasedanalyzer:APPENDING RESULT: <(göz_Noun)(-)(göz:noun_S + ler:a3pl_S + in:p2sg_S + nom_ST)>
# 2023-12-25 12:16:55,891 - zeyrek.rulebasedanalyzer - WARNING
# Msg: APPENDING RESULT: <(göz_Noun)(-)(göz:noun_S + ler:a3pl_S + in:p2sg_S + nom_ST)>
# WARNING:zeyrek.rulebasedanalyzer:APPENDING RESULT: <(gözlük_Noun)(-)(gözlük:noun_S + ler:a3pl_S + pnon_S + in:gen_ST)>
# 2023-12-25 12:16:55,905 - zeyrek.rulebasedanalyzer - WARNING
# Msg: APPENDING RESULT: <(gözlük_Noun)(-)(gözlük:noun_S + ler:a3pl_S + pnon_S + in:gen_ST)>
# WARNING:zeyrek.rulebasedanalyzer:APPENDING RESULT: <(gözlük_Noun)(-)(gözlük:noun_S + ler:a3pl_S + in:p2sg_S + nom_ST)>
# 2023-12-25 12:16:55,912 - zeyrek.rulebasedanalyzer - WARNING
# ...

# %% [markdown]
# # Zemberek ile Normalization

# %%
from zemberek import (
    TurkishSpellChecker,
    TurkishSentenceNormalizer,
    TurkishMorphology,
)


examples = ["Yrn okua gidicem",
            "Tmm, yarin havuza giricem ve aksama kadar yaticam :)",
            "ah aynen ya annemde fark ettı siz evinizden cıkmayın diyo",
            "gercek mı bu? Yuh! Artık unutulması bile beklenmiyo",
            "Hayır hayat telaşm olmasa alacam buraları gökdelen dikicem.",
            "yok hocam kesınlıkle oyle birşey yok",
            "herseyi soyle hayatında olmaması gerek bence boyle ınsanların falan baskı yapıyosa",
            "email adresim zemberek_python@loodos.com",
            "Kredi başvrusu yapmk istiyrum.",
            "Bankanizin hesp blgilerini ogrenmek istyorum."]

morphology = TurkishMorphology.create_with_defaults()
normalizer = TurkishSentenceNormalizer(morphology)
spell_checker = TurkishSpellChecker(morphology)
# Out:
# INFO:zemberek.morphology.turkish_morphology:TurkishMorphology instance initialized in 18.618207931518555
# 2023-12-25 12:19:54,968 - zemberek.morphology.turkish_morphology - INFO
# Msg: TurkishMorphology instance initialized in 18.618207931518555

# %%
for example in examples:
    print(example)
    print(normalizer.normalize(example), "\n")
# Out:
# Yrn okua gidicem
# yarın okula gideceğim
#
# Tmm, yarin havuza giricem ve aksama kadar yaticam :)
# tamam , yarın havuza gireceğim ve akşama kadar yatacağım :)
#
# ah aynen ya annemde fark ettı siz evinizden cıkmayın diyo
# ah aynen ya annemde fark etti siz evinizden çıkmayın diyor
#
# gercek mı bu? Yuh! Artık unutulması bile beklenmiyo
# gerçek mi bu ? yuh ! artık unutulması bile beklenmiyor
#
# Hayır hayat telaşm olmasa alacam buraları gökdelen dikicem.
# hayır hayat telaşı olmasa alacağım buraları gökdelen dikeceğim .
#
# yok hocam kesınlıkle oyle birşey yok
# yok hocam kesinlikle öyle bir şey yok
#
# herseyi soyle hayatında olmaması gerek bence boyle ınsanların falan baskı yapıyosa
# herşeyi söyle hayatında olmaması gerek bence böyle insanların falan baskı yapıyorsa
#
# email adresim zemberek_python@loodos.com
# mail adresim zemberek_python@loodos.com
#
# Kredi başvrusu yapmk istiyrum.
# kredi başvurusu yapmak istiyorum .
#
# Bankanizin hesp blgilerini ogrenmek istyorum.
# ...

# %%
wrong_words = ["okuyablirim", "tartısıyor", "Ankar'ada", "knlıca", "yapablrim", "kıredi", "geldm", "geliyom", "aldm", "asln"]
for wrong_word in wrong_words:
    print(wrong_word + " = " + ' '.join(spell_checker.suggest_for_word(wrong_word)))
# Out:
# okuyablirim = okuyabilirim
# tartısıyor = tartışıyor tartılıyor
# Ankar'ada = Ankara'da Ankara'ya Ankara'dan Ankara'ca Antara'da Ankara'na Ankara'ma Ankara'mda Anakara'da Angara'da Ankaray'a Ankaray'da Ankara'nda
# knlıca = kanlıca kanlıca kılıca anlıca kınlıca kalıca
# yapablrim =
# kıredi = kredi küredi
# geldm = geldi geldim gelim gelem
# geliyom = geliyor geliyim
# aldm = aldı alım aldım alem alim alim alam aldi aldo Aldo'm Aldi'm Al'da Al'dı Al'ım alda Al'dım
# asln = asla aslan aslan aslı aslı asli aslen asan asın aslin As'lan As'ın asin Aslı'n As'la aslın assn As'lın As'lı
